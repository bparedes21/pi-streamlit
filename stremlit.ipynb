# %%
import ccxt

# %%
import pandas as pd

# %%
import pandas as pd
import requests
markets = requests.get('https://ftx.com/api/markets').json()
keys_ñl=markets.keys()
df = pd.DataFrame(markets['result'])
df.set_index('name', inplace = False)
btc_df=df[df["name"]=="FTT/USD"]

# %%
btc_df
# Out:
#         name  enabled  postOnly  priceIncrement  sizeIncrement  \
# 313  FTT/USD     True     False           0.001            0.1
#
#      minProvideSize    last     bid     ask   price  ...  \
# 313             0.1  23.948  23.935  23.942  23.942  ...
#
#     highLeverageFeeExempt largeOrderThreshold change1h  change24h changeBod  \
# 313                  True               280.0      0.0   0.039601 -0.008038
#
#     quoteVolume24h  volumeUsd24h  priceHigh24h  priceLow24h  tokenizedEquity
# 313   1.421161e+07  1.421161e+07        24.353       22.898              NaN
#
# [1 rows x 27 columns]

# %% [markdown]
# Chainlink	LINK
# Polygon	MATIC
# UNUS SED LEO	LEO
# USD Coin USDC
# NEAR Protocol	NEAR
# XRP XRP
# Binance USD BUSD
# Cardano ADA
# Stellar XLM
# Dogecoin DOGE]

# %%
        trace=go.Pie(labels=labels,values=datavals,
                                    hovertemplate = "%{label}: <br>Value: %{value} ",
                                    showlegend=True,
                                    textposition='inside',
                                    )
        layout = go.Layout(
        title = 'Percentage of {}'.format(col),
        height=600,
        margin=go.Margin(l=0, r=200, b=100, t=100, pad=4)   # Margins - Left, Right, Top Bottom, Padding
        )
                        
        data = [trace]
        fig = go.Figure(data=data,layout = layout)
        st.plotly_chart(fig)


        st.bar_chart(df_stadistic)

# %%
li=[1500,1200 ,1700 ,1300 ,1800]

def funcion_calcular_varianza(li):

  suma=0
  for i in li:
    suma=suma+i
  #print("suma: ",suma)
  promedio2=suma/5
  #print("promedio2: ",promedio2)
  nuevali=[]
  for i in li:

      resta_i=i-promedio2
      #print("varianza: ",resta_i)
      nuevali.append(resta_i**2)
  ##print("nuevali: ",nuevali)
  suma2=0
  for i in nuevali:
    suma2=suma2+i
  #print("suma: ",suma2)
  varianza=suma2/5
  #print("promedio3: ",varianza)
  std_dev=varianza** (0.5)
  return  varianza,std_dev

# %%
varianza_USD,desv_estd_USD=funcion_calcular_varianza(li)

# %%
def funcion_obtener_price_coin_actual():
    import pandas as pd
    import requests
    markets = requests.get('https://ftx.com/api/markets').json()
    keys_ñl=markets.keys()
    df = pd.DataFrame(markets['result'])
    df.set_index('name', inplace = False)
    list_names=[]
    lista_precio_actual=[]
    lista_conversion=[]
    precio_sin_media=[]
    list_monedas=["LINK","MATIC","USDT","NEAR","XRP","DOT","DAI","SOL","DOGE"]
    for moneda in list_monedas:
        string_moneda=moneda+"/USD"
        #print(string_moneda)
        btc_df=df[df["name"]==string_moneda]

        price_val=round(float(btc_df['price']),2)
        #print(price_val)
        lista_precio_actual.append(price_val)
        list_names.append(moneda)
        #conversion
        val_conversion=1/price_val
        lista_conversion.append(val_conversion)
        #print(list_names)
    col=["precio","moneda","precio_usd"]
    c = zip(lista_precio_actual,list_names,lista_conversion)
    df3=pd.DataFrame(c)
#data_ML_car.loc[data_ML_car['carwidth']]=df[
    df3.columns=col    
    varianza_coin,desv_estd_coin=funcion_calcular_varianza(lista_precio_actual)
    varianza_coin=round(varianza_coin,2)
    desv_estd_coin=round(desv_estd_coin,2) 
    varianza_USD,desv_estd_USD=funcion_calcular_varianza(lista_conversion)
    varianza_USD=round(varianza_USD,2)
    desv_estd_USD=round(desv_estd_USD,2)
    return df3,varianza_coin,desv_estd_coin,varianza_USD,desv_estd_USD

# %%
df_stadistic,varianza_coin,desv_estd_coin,varianza_USD,desv_estd_USD=funcion_obtener_price_coin_actual()

print(varianza_coin,desv_estd_coin,varianza_USD,desv_estd_USD)
df_stadistic
# Out:
# 224.85 15.0 53.18 7.29
#    precio moneda  precio_usd
# 0    7.72   LINK    0.129534
# 1    0.75  MATIC    1.333333
# 2    1.00   USDT    1.000000
# 3    3.58   NEAR    0.279330
# 4    0.44    XRP    2.272727
# 5    6.41    DOT    0.156006
# 6    1.00    DAI    1.000000
# 7   33.57    SOL    0.029789
# 8    0.06   DOGE   16.666667

# %%
mon=df_stadistic[df_stadistic["moneda"]=="XRP"]

# %%
df_stadistic
# Out:
#    precio moneda  precio_usd
# 0    7.90   LINK    0.126582
# 1    0.75  MATIC    1.333333
# 2    1.00   USDT    1.000000
# 3    3.59   NEAR    0.278552
# 4    0.44    XRP    2.272727
# 5    6.43    DOT    0.155521
# 6    1.00    DAI    1.000000
# 7   33.62    SOL    0.029744
# 8    0.06   DOGE   16.666667

# %%
x=float(mon["precio"].values)

# %%
x
# Out:
# 0.44

# %%
mon
# Out:
#    precio moneda  precio_usd
# 4    0.44    XRP    2.272727

# %%
x=float(price_val)

# %%
x
# Out:
# 0.44

# %%
import pandas as pd
import requests
markets = requests.get('https://ftx.com/api/markets').json()
keys_ñl=markets.keys()
df = pd.DataFrame(markets['result'])
df.set_index('name', inplace = False)
list_names=[]
lista_precio_actual=[]
lista_conversion=[]
precio_sin_media=[]
list_monedas=["LINK","MATIC","USDT","NEAR","XRP","DOT","DAI","XLM","DOGE"]

# %%
import numpy as np

# %%
lista_precios=list(df["price"])

# %%
lista_precios=pd.DataFrame(lista_precios)

# %%
lista_precios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935 entries, 0 to 934
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       930 non-null    float64
# dtypes: float64(1)
# memory usage: 7.4 KB

# %%
price_val
# Out:
# 4    0.44
# Name: precio, dtype: float64

# %%
import pandas as pd
import requests
markets = requests.get('https://ftx.com/api/markets').json()
keys_ñl=markets.keys()
df = pd.DataFrame(markets['result'])
df.set_index('name', inplace = False)
# Out:
#               enabled  postOnly  priceIncrement  sizeIncrement  \
# name
# 1INCH-PERP       True     False    1.000000e-04        1.00000
# 1INCH-0930       True     False    1.000000e-04        1.00000
# 1INCH-1230       True     False    1.000000e-04        1.00000
# 1INCH/USD        True     False    1.000000e-04        1.00000
# AAPL-0930        True     False    1.000000e-02        0.01000
# ...               ...       ...             ...            ...
# XTZBULL/USDT     True     False    1.000000e-08    10000.00000
# XTZHALF/USD      True     False    2.500000e-01        0.00001
# XTZHEDGE/USD     True     False    5.000000e-03        0.00100
# ZECBEAR/USD      True     False    1.000000e-06      100.00000
# ZECBULL/USD      True     False    5.000000e-08     1000.00000
#
#               minProvideSize         last          bid          ask  \
# name
# 1INCH-PERP           1.00000     0.586900     0.586800     0.586900
# ...

# %%
df.columns
# Out:
# Index(['name', 'enabled', 'postOnly', 'priceIncrement', 'sizeIncrement',
#        'minProvideSize', 'last', 'bid', 'ask', 'price', 'type', 'futureType',
#        'baseCurrency', 'isEtfMarket', 'quoteCurrency', 'underlying',
#        'restricted', 'highLeverageFeeExempt', 'largeOrderThreshold',
#        'change1h', 'change24h', 'changeBod', 'quoteVolume24h', 'volumeUsd24h',
#        'priceHigh24h', 'priceLow24h', 'tokenizedEquity'],
#       dtype='object')

# %% [markdown]
# Esto quiere decir que, en media, la diferencia entre los precios de las distintas monedas será de

# %% [markdown]
# desviacion tipica es la raiz cuadrada de la varianza

# %%
promedio3** (0.5)
# Out:
# 228.0350850198276

# %% [markdown]
# Esto quiere decir que, en media, la diferencia entre los precios de las distintas monedas será de

# %%
col=["col"]
df3=pd.DataFrame(li)
#data_ML_car.loc[data_ML_car['carwidth']]=df[
df3.columns=col

# %%
df3.std()
for i in range(1):
    varianza=df3.iloc[:,i].var()
    print("varianza: ",varianza-promedio)
# Out:
# varianza:  62700.945555555554

# %%
varianza_l=statistics.variance(li) 
print(statistics.stdev(li))
print(varianza_l)
# Out:
# 254.95097567963924
# 65000

# %%
btc_df.columns
# Out:
# Index(['name', 'enabled', 'postOnly', 'priceIncrement', 'sizeIncrement',
#        'minProvideSize', 'last', 'bid', 'ask', 'price', 'type', 'futureType',
#        'baseCurrency', 'isEtfMarket', 'quoteCurrency', 'underlying',
#        'restricted', 'highLeverageFeeExempt', 'largeOrderThreshold',
#        'change1h', 'change24h', 'changeBod', 'quoteVolume24h', 'volumeUsd24h',
#        'priceHigh24h', 'priceLow24h', 'tokenizedEquity'],
#       dtype='object')

# %%
btc_df["price"]
# Out:
# 313    23.094
# Name: price, dtype: float64

# %%
btc_df["type"]
# Out:
# 313    spot
# Name: type, dtype: object

# %%
btc_df["futureType"]
# Out:
# 313    None
# Name: futureType, dtype: object

# %%
btc_df.isna().sum()

# %%
btc_df

# %%
import pandas as pd
import requests

# %%
import pandas as pd
import requests

def funcion_obtener_moneda():
    endpoint_url='https://ftx.com/api/markets'
    base_currency = 'FTT'
    quote_currency = 'USD'
    # Specify the base and quote currencies to get single market data
    request_url = f'{endpoint_url}/{base_currency}/{quote_currency}'
    df = pd.DataFrame(requests.get(request_url).json())
    #df['result']
    
    return

# %%
from datetime import datetime
import pandas as pd

# %%
def funcion_crearDF_por_año():
    endpoint_url='https://ftx.com/api/markets'
    base_currency = 'DOT'
    quote_currency = 'USD'

    request_url = f'{endpoint_url}/{base_currency}/{quote_currency}'
    import pandas as pd
    import requests
    from datetime import datetime
    # 1 day = 60 * 60 * 24 (60 segundos 1 (minuto) por 60 minutos(1 hora) por 24 (horas))
    daily=str(60*60*24)
    #Obtengo los datos a partir de 2022
    start_date = datetime(2019, 1, 1).timestamp()
    #Get para obtener los datos de la API en formato JSON
    # Get the historical market data as JSON
    historical = requests.get(
        f'{request_url}/candles?resolution={daily}&start_time={start_date}'
    ).json()
    # Convert JSON to Pandas DataFrame
    df = pd.DataFrame(historical['result'])
    # Convert time to date
    df['date'] = pd.to_datetime(
        df['time']/1000, unit='s', origin='unix'
    ) 
    pd.DataFrame(df ,columns=[	"open",	"high",	"low",	"close","date"])


    # Remove unnecessar columns
    #df.drop(['startTime', 'time'], axis=1, inplace=True)
    df['año'] = pd.DatetimeIndex(df['date']).year
    df['mes'] = pd.DatetimeIndex(df['date']).month
    df['dia'] = pd.DatetimeIndex(df['date']).day
    df['volume']=round(df['volume'],1)
    return df

# %%
df_año_2019=funcion_crearDF_por_año()

# %%
df_año_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1160 entries, 0 to 1159
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   startTime  1160 non-null   object
#  1   time       1160 non-null   float64
#  2   open       1160 non-null   float64
#  3   high       1160 non-null   float64
#  4   low        1160 non-null   float64
#  5   close      1160 non-null   float64
#  6   volume     1160 non-null   float64
#  7   date       1160 non-null   datetime64[ns]
#  8   año        1160 non-null   int64
#  9   mes        1160 non-null   int64
#  10  dia        1160 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(3), object(1)
# memory usage: 99.8+ KB

# %%
mayor_mes=df_año_2019["año"].max()
df_mes=df_año_2019[df_año_2019["mes"]==mayor_mes]
mayor_dia=df_mes["dia"].max()
df_dia=df_mes[df_mes["dia"]==mayor_mes]

# %%
año_mes=df_año_2019["año"].max()
año_mes=df_año_2019["año"].min()

# %%
año_mes
año_mes
# Out:
# 2021

# %%
mayor_mes
# Out:
# 2022

# %%
array_v=df_dia["open"].values

# %%
array_v[0]
# Out:
# 26.041

# %%
open=float(array_v[0])

# %%
type(open)
# Out:
# float

# %%
df_mes=df_año_2019[df_año_2019["mes"]==mayor_mes]
mayor_dia=df_mes["dia"].max()
df_dia=df_mes[df_mes["dia"]==mayor_mes]
df_dia

# %%
mayor_dia=df_mes["dia"].max()
df_dia=df_mes[df_mes["dia"]==mayor_mes]
df_dia

# %%
df_dia=df_mes[df_mes["dia"]==mayor_mes]
df_dia

# %%
df_dia
# Out:
#                      startTime          time    open    high     low   close  \
# 250  2022-09-09T00:00:00+00:00  1.662682e+12  26.041  27.909  26.005  27.239
#
#          volume       date   año  mes  dia
# 250  17499348.6 2022-09-09  2022    9    9

# %%
print(df_año_2019.head(4))
# Out:
#                    startTime          time  open  high   low  close  \
# 0  2019-07-29T00:00:00+00:00  1.564358e+12  1.01  1.66  1.01   1.65
# 1  2019-07-30T00:00:00+00:00  1.564445e+12  1.65  1.96  1.59   1.87
# 2  2019-07-31T00:00:00+00:00  1.564531e+12  1.87  1.96  1.71   1.71
# 3  2019-08-01T00:00:00+00:00  1.564618e+12  1.71  1.81  1.70   1.76
#
#       volume       date   año  mes  dia
# 0  1407998.4 2019-07-29  2019    7   29
# 1  1078227.7 2019-07-30  2019    7   30
# 2   934389.0 2019-07-31  2019    7   31
# 3   700564.6 2019-08-01  2019    8    1

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3064 entries, 0 to 1157
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    3064 non-null   float64
#  1   high    3064 non-null   float64
#  2   low     3064 non-null   float64
#  3   close   3064 non-null   float64
#  4   volume  3064 non-null   float64
#  5   date    3064 non-null   datetime64[ns]
#  6   año     3064 non-null   int64
#  7   mes     3064 non-null   int64
#  8   dia     3064 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(3)
# memory usage: 239.4 KB

# %%
df_concat['date'] = pd.to_datetime(df_concat['date'], format="%Y %m/%d")

# %%
df_stadistic,varianza_coin,desv_estd_coin,varianza_USD,desv_estd_USD=funcion_obtener_price_coin_actual()

# %%
df_stadistic
# Out:
#    precio moneda  precio_usd
# 0    7.69   LINK    0.130039
# 1    0.74  MATIC    1.351351
# 2    1.00   USDT    1.000000
# 3    3.55   NEAR    0.281690
# 4    0.44    XRP    2.272727
# 5    6.38    DOT    0.156740
# 6    1.00    DAI    1.000000
# 7   33.36    SOL    0.029976
# 8    0.06   DOGE   16.666667

# %%
all_columns_names = df_stadistic.columns.tolist()

# %%
all_columns_names
# Out:
# ['precio', 'moneda', 'precio_usd']

# %%
max_da=df_concat['date'].dt.year.max()

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3064 entries, 0 to 1157
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    3064 non-null   float64
#  1   high    3064 non-null   float64
#  2   low     3064 non-null   float64
#  3   close   3064 non-null   float64
#  4   volume  3064 non-null   float64
#  5   date    3064 non-null   datetime64[ns]
#  6   año     3064 non-null   int64
#  7   mes     3064 non-null   int64
#  8   dia     3064 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(3)
# memory usage: 239.4 KB

# %%
max_año=datos_año["date"].max()

# %%
type(max_da)
# Out:
# numpy.int64

# %%
datos_mes=df_concat[df_concat['date'].dt.month==12]

# %%
datos_mes
# Out:
#        open    high     low   close      volume       date   año  mes  dia
# 333  50.696  51.714  49.442  50.810  58200593.0 2021-12-01  2021   12    1
# 334  50.810  50.828  48.228  49.372  54802262.4 2021-12-02  2021   12    2
# 335  49.372  49.906  45.403  47.080  51933163.7 2021-12-03  2021   12    3
# 336  47.080  47.287  37.400  44.015  82043953.9 2021-12-04  2021   12    4
# 337  44.015  44.739  42.080  43.871  39186153.0 2021-12-05  2021   12    5
# ..      ...     ...     ...     ...         ...        ...   ...  ...  ...
# 882  42.587  43.652  42.190  42.614  27327405.7 2021-12-27  2021   12   27
# 883  42.614  42.615  39.410  40.023  42262231.9 2021-12-28  2021   12   28
# 884  40.023  40.529  38.110  38.530  28634027.6 2021-12-29  2021   12   29
# 885  38.530  40.350  38.053  38.854  31862266.1 2021-12-30  2021   12   30
# 886  38.854  40.350  36.359  38.255  67268086.3 2021-12-31  2021   12   31
#
# [186 rows x 9 columns]

# %%
min_dato=df_mes["mes"].min()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Python310\lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:41, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'mes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\ROXI\OneDrive\Escritorio\pi03\pi-streamlit\stremlit.ipynb Celda 33 in <module>
# ...

# %%
type(df_mes)
# Out:
# pandas.core.series.Series

# %%
str_dat=str(min_dato)

# %%
min_dato
# Out:
# 1

# %%
dt = datetime.date(min_dato)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ROXI\OneDrive\Escritorio\pi03\pi-streamlit\stremlit.ipynb Celda 36 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ROXI/OneDrive/Escritorio/pi03/pi-streamlit/stremlit.ipynb#Y131sZmlsZQ%3D%3D?line=0'>1</a> dt = datetime.date(min_dato)
#
# TypeError: descriptor 'date' for 'datetime.datetime' objects doesn't apply to a 'numpy.int64' object

# %%
print (dt)
# Out:
# 1900-01-01 00:00:00

# %%
type(dt)
# Out:
# datetime.datetime

# %%
dt
# Out:
# datetime.datetime(1900, 1, 1, 0, 0)

# %%
df_año_2019
# Out:
#         open    high     low   close      volume       date   año  mes  dia
# 0      1.010   1.660   1.010   1.650   1407998.4 2019-07-29  2019    7   29
# 1      1.650   1.960   1.590   1.870   1078227.7 2019-07-30  2019    7   30
# 2      1.870   1.960   1.710   1.710    934389.0 2019-07-31  2019    7   31
# 3      1.710   1.810   1.700   1.760    700564.6 2019-08-01  2019    8    1
# 4      1.760   1.810   1.740   1.780    723573.6 2019-08-02  2019    8    2
# ...      ...     ...     ...     ...         ...        ...   ...  ...  ...
# 1153  23.884  24.121  23.554  23.690   5368312.8 2022-09-24  2022    9   24
# 1154  23.690  23.957  23.291  23.510   4908497.3 2022-09-25  2022    9   25
# 1155  23.510  24.251  23.231  24.214  18163700.7 2022-09-26  2022    9   26
# 1156  24.214  25.126  23.358  23.633  25275516.2 2022-09-27  2022    9   27
# 1157  23.636  23.941  22.850  23.841   9273174.1 2022-09-28  2022    9   28
#
# [1158 rows x 9 columns]

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1076 entries, 0 to 268
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    1076 non-null   float64
#  1   high    1076 non-null   float64
#  2   low     1076 non-null   float64
#  3   close   1076 non-null   float64
#  4   volume  1076 non-null   float64
#  5   date    1076 non-null   datetime64[ns]
#  6   año     1076 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 67.2 KB

# %%
df_concat["año"].min()
df_concat["año"].max()
# Out:
# 2022

# %%
from datetime import datetime

# %%
min_date = df_concat[df_concat["año"]==2019]
min_date
# Out:
#       open   high    low  close     volume       date   año  mes  dia
# 0    1.010  1.660  1.010  1.650  1407998.4 2019-07-29  2019    7   29
# 1    1.650  1.960  1.590  1.870  1078227.7 2019-07-30  2019    7   30
# 2    1.870  1.960  1.710  1.710   934389.0 2019-07-31  2019    7   31
# 3    1.710  1.810  1.700  1.760   700564.6 2019-08-01  2019    8    1
# 4    1.760  1.810  1.740  1.780   723573.6 2019-08-02  2019    8    2
# ..     ...    ...    ...    ...        ...        ...   ...  ...  ...
# 151  2.140  2.163  2.138  2.151   126644.0 2019-12-27  2019   12   27
# 152  2.151  2.187  2.148  2.179   132989.9 2019-12-28  2019   12   28
# 153  2.179  2.250  2.168  2.211   253400.7 2019-12-29  2019   12   29
# 154  2.211  2.211  2.151  2.158   178846.8 2019-12-30  2019   12   30
# 155  2.158  2.183  2.142  2.142   110148.0 2019-12-31  2019   12   31
#
# [156 rows x 9 columns]

# %%
min_año_date=datetime.date(df_concat["date"].min())

# %%
min_año_date
# Out:
# Timestamp('2022-09-27 00:00:00')

# %%
df.set_index('date', inplace = True)

# %%
df_concat['año'] = pd.DatetimeIndex(df_concat['date']).year

# %%
df_concat['mes'] = pd.DatetimeIndex(df['date']).month
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ROXI\OneDrive\Escritorio\pi03\pi-streamlit\stremlit.ipynb Celda 22 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ROXI/OneDrive/Escritorio/pi03/pi-streamlit/stremlit.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> df_concat['mes'] = pd.DatetimeIndex(df['date']).month
#
# NameError: name 'df' is not defined

# %%
df_concat['dia'] = pd.DatetimeIndex(df['date']).day

# %%
df_concat['volume']=round(df['volume'],1)

# %%
df.head(5)
# Out:
#      open    high     low   close      volume       date
# 0  40.209  40.630  39.300  40.159  29846442.7 2022-01-02
# 1  40.159  41.600  39.346  40.222  74789283.0 2022-01-03
# 2  40.222  43.800  39.250  41.375  74206934.8 2022-01-04
# 3  41.375  42.770  37.113  38.054  83989000.3 2022-01-05
# 4  38.054  39.362  36.411  38.613  66624506.8 2022-01-06

# %% [markdown]
# volumen por año mes

# %%
df_dia=df_año_2022[df_año_2022['año']==2022]

# %%
df_dia
# Out:
#                      startTime          time    open    high     low   close  \
# 0    2022-01-02T00:00:00+00:00  1.641082e+12  40.209  40.630  39.300  40.159
# 1    2022-01-03T00:00:00+00:00  1.641168e+12  40.159  41.600  39.346  40.222
# 2    2022-01-04T00:00:00+00:00  1.641254e+12  40.222  43.800  39.250  41.375
# 3    2022-01-05T00:00:00+00:00  1.641341e+12  41.375  42.770  37.113  38.054
# 4    2022-01-06T00:00:00+00:00  1.641427e+12  38.054  39.362  36.411  38.613
# ..                         ...           ...     ...     ...     ...     ...
# 266  2022-09-25T00:00:00+00:00  1.664064e+12  23.690  23.957  23.291  23.510
# 267  2022-09-26T00:00:00+00:00  1.664150e+12  23.510  24.251  23.231  24.214
# 268  2022-09-27T00:00:00+00:00  1.664237e+12  24.214  25.126  23.358  23.633
# 269  2022-09-28T00:00:00+00:00  1.664323e+12  23.636  24.353  22.850  24.091
# 270  2022-09-29T00:00:00+00:00  1.664410e+12  24.091  24.323  23.982  24.273
#
#          volume       date   año  mes  dia
# ...

# %%
apertura=df_dia["open"]
maximo_dia=df_dia["high"]
minimo_dia=df_dia["low"]
cierre=df_dia["close"]
c=df_dia["volume"]

# %%
apertura_val=round(float(df_dia['open']),2)
maximo_dia=round(float(df_dia["high"]),2)
minimo_dia=round(float(df_dia["low"]),2)
cierre_dia=round(float(df_dia["close"]),2)
volume_dia=round(float(df_dia["volume"]),2)

# %%
suma_dia=

# %%
cierre_dia
# Out:
# 23.63

# %%
import statistics
lista_dia=[maximo_dia,minimo_dia,apertura_val]

# %%
statistics.median(lista_dia)
# Out:
# 24.21

# %% [markdown]
# promedio=23,6400

# %% [markdown]
# open	apertura
# high    maximo
# low     minimo
# close   ultimo
# volume	volumen

# %%
df['volume'].sum()
# Out:
# 7169583432.6872

# %%
import plotly.express as px

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    269 non-null    float64
#  1   high    269 non-null    float64
#  2   low     269 non-null    float64
#  3   close   269 non-null    float64
#  4   volume  269 non-null    float64
#  5   date    269 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 12.7 KB

# %%
import pandas as pd
pd.options.plotting.backend = "plotly"
new_df=df["year"]

fig = new_df.plot.bar()
fig.show()

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df["date"].max()
# Out:
# Timestamp('2022-09-27 00:00:00')

# %%
df["date"].min()
# Out:
# Timestamp('2022-01-02 00:00:00')

# %%
list_col_2019=df_año_2019.columns
cpy=pd.DataFrame()
cpy=df_año_2019["low"].min()
cpy["high"]=df_año_2019["high"].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ROXI\OneDrive\Escritorio\pi03\pi-streamlit\stremlit.ipynb Celda 97 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/ROXI/OneDrive/Escritorio/pi03/pi-streamlit/stremlit.ipynb#Y214sZmlsZQ%3D%3D?line=1'>2</a> cpy=pd.DataFrame()
#       <a href='vscode-notebook-cell:/c%3A/Users/ROXI/OneDrive/Escritorio/pi03/pi-streamlit/stremlit.ipynb#Y214sZmlsZQ%3D%3D?line=2'>3</a> cpy=df_año_2019["low"].min()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ROXI/OneDrive/Escritorio/pi03/pi-streamlit/stremlit.ipynb#Y214sZmlsZQ%3D%3D?line=3'>4</a> cpy["high"]=df_año_2019["high"].max()
#
# TypeError: 'numpy.float64' object does not support item assignment

# %%
df_año_2019=df_año_2019.set_index('date', inplace = False)
df_año_2019=df_año_2019.drop(columns=["startTime","time","año","mes","dia"])
px.line(df_año_2019, x = df_año_2019.index, y = df_año_2019.columns)

# %%
#import matplotlib
#import matplotlib.pyplot as plt
#import seaborn as sns
#sns.countplot(x=df_año_2019["date"],data=df_año_2019[['open', 'high', 'low', 'close', 'volume']])

px.line(df_año_2019, x = df_año_2019.index, y = df_año_2019.columns)

# %%
df_año_2019
# Out:
#                             startTime          time    open    high     low  \
# date
# 2019-07-29  2019-07-29T00:00:00+00:00  1.564358e+12   1.010   1.660   1.010
# 2019-07-30  2019-07-30T00:00:00+00:00  1.564445e+12   1.650   1.960   1.590
# 2019-07-31  2019-07-31T00:00:00+00:00  1.564531e+12   1.870   1.960   1.710
# 2019-08-01  2019-08-01T00:00:00+00:00  1.564618e+12   1.710   1.810   1.700
# 2019-08-02  2019-08-02T00:00:00+00:00  1.564704e+12   1.760   1.810   1.740
# ...                               ...           ...     ...     ...     ...
# 2022-09-25  2022-09-25T00:00:00+00:00  1.664064e+12  23.690  23.957  23.291
# 2022-09-26  2022-09-26T00:00:00+00:00  1.664150e+12  23.510  24.251  23.231
# 2022-09-27  2022-09-27T00:00:00+00:00  1.664237e+12  24.214  25.126  23.358
# 2022-09-28  2022-09-28T00:00:00+00:00  1.664323e+12  23.636  24.353  22.850
# 2022-09-29  2022-09-29T00:00:00+00:00  1.664410e+12  24.091  24.170  24.084
#
#              close      volume   año  mes  dia
# ...

# %%
sns.lineplot(data = df_año_2020)
# Out:
# <AxesSubplot:>

# %%
cpy
# Out:
# Empty DataFrame
# Columns: [low, high]
# Index: []

# %%
#print("varianza: ",resta_i)
    
##print("nuevali: ",nuevali)
  
df=cpy[["high","low"]]

fig = px.line(df, x=df_año_2019["date"], y=	df, color='low', markers=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ROXI\OneDrive\Escritorio\pi03\pi-streamlit\stremlit.ipynb Celda 96 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/ROXI/OneDrive/Escritorio/pi03/pi-streamlit/stremlit.ipynb#Y145sZmlsZQ%3D%3D?line=0'>1</a> list_col_2019=df_año_2019.columns
#       <a href='vscode-notebook-cell:/c%3A/Users/ROXI/OneDrive/Escritorio/pi03/pi-streamlit/stremlit.ipynb#Y145sZmlsZQ%3D%3D?line=1'>2</a> cpy=df_año_2019.copy()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ROXI/OneDrive/Escritorio/pi03/pi-streamlit/stremlit.ipynb#Y145sZmlsZQ%3D%3D?line=2'>3</a> cpy["low"]=df_año_2019[df_año_2019["low"]==df_año_2019["low"].min()]
# ...

# %%
fig2 = px.bar(df)
fig2.show()

# %%
import streamlit as st
import datetime

today = datetime.date.today()
tomorrow = today + datetime.timedelta(days=1)
start_date = st.date_input('Start date', today)
end_date = st.date_input('End date', tomorrow)

# %%
## Range selector MES
cols2,_ = st.columns((1,2)) # To make it narrower
format = 'MMM DD, YYYY'  # format output
start_date1 =datetime.date(df_concat_año["mes"].min())
end_date = datetime.date(df_concat_año["mes"].max())
max_days = end_date-start_date1

slider = cols2.slider('Select date', min_value=start_date1, value=end_date ,max_value=end_date, format=format)
## Sanity check
st.table(pd.DataFrame([[start_date1, slider, end_date]],
            columns=['start',
                    'selected',
                    'end'],
            index=['date']))

st.write("MES seleccionado",slider) 

df_concat_año
## Range selector DIA
cols1,_ = st.columns((1,2)) # To make it narrower
format = 'MMM DD, YYYY'  # format output
start_date2 =datetime.date(df_concat["dia"].min())
end_date = datetime.date(df_concat["dia"].max())
max_days = end_date-start_date2

slider = cols1.slider('Select date', min_value=start_date2, value=end_date ,max_value=end_date, format=format)
## Sanity check
st.table(pd.DataFrame([[start_date2, slider, end_date]],
            columns=['start',
                    'selected',
                    'end'],
            index=['date']))

st.write("DIA seleccionado",slider)

# %%
options = {
    "xAxis": {
        "type": "category",
        "data": ["LINK","MATIC","USDT","NEAR","XRP","DOT","DAI","SOL","DOGE"],
    },
    "yAxis": {"type": "value"},
    "series": [
        {"data":df_stadistic["precio"] , "type": "line"}
    ],
}
st_echarts(options=options)
